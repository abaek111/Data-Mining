# %% [markdown]
# <a href="https://colab.research.google.com/github/abaek111/Data-Mining/blob/main/decisiontree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris()
features = iris['data']
target = iris['target']

# %%
decisiontree = DecisionTreeClassifier(random_state=0,
    max_depth=None, min_samples_split=2,
    min_samples_leaf=1,, min_weight_fraction_leaf=0,
    max_leaf_nodes=None, min_impurity_decrease=0)
# Out:
#   File "<ipython-input-13-df77dab64d8c>", line 3
#     min_samples_leaf=1,, min_weight_fraction_leaf=0,
#                        ^
# SyntaxError: invalid syntax

# %%
model = decisiontree.fit(features, target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-94284745f2ba> in <module>()
# ----> 1 model = Decisiontree.fit(features, target)
#
# NameError: name 'Decisiontree' is not defined

# %%
observation = [[5, 4, 3, 2]]
model.predict(observation)
model.predict_proba(observation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6505781f408a> in <module>()
#       1 observation = [[5, 4, 3, 2]]
# ----> 2 model.predict(observation)
#       3 model.predict_proba(observation)
#
# NameError: name 'model' is not defined

# %%
import pydotplus
from sklearn import tree
dot_data = tree.export_graphviz(decisiontree, out_file=None,
     feature_names=iris['feature_names'],
      class_names=iris['target_names'])
from IPython.display import Image
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
graph.write_png("iris.png")
